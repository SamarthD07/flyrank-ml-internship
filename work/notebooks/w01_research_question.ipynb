# %% [markdown]
# <a href="https://colab.research.google.com/github/SamarthD07/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SamarthD07/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# My lane: Refresh / Content Opportunity Scoring.
#
# I want to identify which pages should be reviewed first for a possible content refresh or improvement. This is useful because a review team has limited time, so the goal is to prioritize pages using observable signals such as search impressions, content age, position, CTR, and recent movement. I chose this lane because it connects directly to the search/content problem and can eventually produce a ranked list of pages with clear reasons for why they deserve attention.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The decision is which pages should be reviewed first for a possible content refresh or improvement. A content or SEO team would use the ranking to decide where to spend limited review time. A wrong recommendation could waste the team's time on a page that does not need attention, while missing a genuinely important page could mean losing an opportunity to improve its search visibility or engagement.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset contains 30,000 pages. The median page has 731 impressions over 90 days and is 236 days old, while the median CTR is 0.07. These numbers show that the dataset contains pages with meaningful search exposure and a range of content ages, making it useful for exploring which pages may deserve review or refresh.

# %%
import os
import subprocess
import sys

REPO_URL = "https://github.com/SamarthD07/flyrank-ml-internship"
REPO_DIR = "flyrank-ml-internship"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)

os.chdir(REPO_DIR)

print("Working directory:", os.getcwd())
# Out:
# Working directory: /content/flyrank-ml-internship/flyrank-ml-internship

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Median impressions:", df["impressions_90d"].median())
print("Median content age (days):", df["content_age_days"].median())
print("Median CTR:", df["ctr"].median())
# Out:
# Rows: 30000
# Median impressions: 731.0
# Median content age (days): 236.0
# Median CTR: 0.07

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This work can identify observed patterns in the dataset and provide directional, decision-support signals for prioritizing pages for review. It can help rank pages that may deserve attention based on the available data. However, it cannot prove that a particular factor causes a change in performance, and it cannot claim to predict Google's ranking algorithm or future search performance. The results should be treated as decision support rather than causal proof.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
